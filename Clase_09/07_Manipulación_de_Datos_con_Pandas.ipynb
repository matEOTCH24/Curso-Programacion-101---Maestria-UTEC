# %% [markdown]
# <a href="https://colab.research.google.com/github/matEOTCH24/Curso-Programacion-101---Maestria-UTEC/blob/main/Clase_09/07_Manipulaci%C3%B3n_de_Datos_con_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.ctic.uni.edu.pe/wp-content/uploads/2022/04/588px-x-348px-web-1.png" alt="HTML5 Icon" width="900" height="350" >

# %% [markdown]
# # **Manipulación de Datos con Pandas**

# %% [markdown]
# **Objetivo**
#
# El objetivo de este laboratorio es capacitar al estudiante con las herramientas y técnicas esenciales para la manipulación de datos utilizando la biblioteca Pandas. Al final del laboratorio, el estudiante será capaz de realizar operaciones básicas y avanzadas en conjuntos de datos, combinarlos, agruparlos y extraer información útil para el análisis.

# %% [markdown]
# **Contenido**
#
# 1. <a href="#item31">Introducción a Pandas</a>
# 2. <a href="#item31">Operaciones Básicas con DataFrames</a>
# 3. <a href="#item31">Combinación de Datasets</a>
# 4. <a href="#item31">Agregación y Agrupamiento</a>
#
# </font>
# </div>
#
#
# ---

# %% [markdown]
# # 1. Introducción a Pandas

# %% [markdown]
# ## 1.1. ¿Qué es Pandas?
#
# Pandas es una biblioteca de código abierto para el lenguaje de programación Python, que proporciona estructuras de datos y herramientas de análisis de datos de alto rendimiento y fáciles de usar. Es fundamental en el campo de la ciencia de datos y el análisis de datos.
#
# **Características clave de Pandas:**
#
# - Estructuras de datos flexibles: Series y DataFrames para datos unidimensionales y bidimensionales.
# - Indexación potente: Permite acceso y manipulación eficientes de datos.
# - Herramientas de limpieza y preparación de datos: Funciones para manejar datos faltantes, duplicados, y más.
# - Integración con otras bibliotecas: Se complementa bien con NumPy, Matplotlib, y otras.

# %% [markdown]
# ## 1.2. Estructuras de datos en Pandas
#
# **Series:** Estructura unidimensional similar a una columna en una tabla.

# %%
import pandas as pd

# Crear una Serie
s = pd.Series([1, 3, 5, 7, 9])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# **DataFrame:** Estructura bidimensional, similar a una hoja de cálculo con filas y columnas.

# %%
# Crear un DataFrame
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos'],
    'Edad': [23, 45, 34],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia']
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    23     Madrid
# 1    Luis    45  Barcelona
# 2  Carlos    34   Valencia

# %% [markdown]
# ## 1.3. Importación y exploración inicial de datos
#
# Importar datos desde un archivo CSV:

# %%
# archivo 'datos.csv'
df = pd.read_csv('datos.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-efd669f86da1> in <cell line: 2>()
#       1 # archivo 'datos.csv'
# ----> 2 df = pd.read_csv('datos.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datos.csv'

# %%
titanic = pd.read_csv('/content/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Exploración inicial:**
#
# Ver las primeras filas:

# %%
print(df.head())  # Muestra las primeras 5 filas
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    23     Madrid
# 1    Luis    45  Barcelona
# 2  Carlos    34   Valencia

# %% [markdown]
# Resumen de información:

# %%
print(df.info())  # Información sobre tipos de datos y valores nulos

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Estadísticas descriptivas:

# %%
print(df.describe())  # Estadísticas básicas de las columnas numéricas

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ##2. Operaciones Básicas con DataFrames

# %% [markdown]
# ###2.1. Acceso a datos
#
# **Conceptos clave:**
#
# - Acceso a columnas y filas.
# - Uso de loc (basado en etiquetas) y iloc (basado en posiciones).

# %% [markdown]
# **Ejemplo:**

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María'],
    'Edad': [23, 45, 34, 29],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla']
}

data = pd.DataFrame(data)
data.to_csv('/content/data', index=False)  # Guardar el DataFrame en un archivo CSV

# %%
pd.read_csv('/content/data')
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    23     Madrid
# 1    Luis    45  Barcelona
# 2  Carlos    34   Valencia
# 3   María    29    Sevilla

# %%
data.Nombre.tolist() #extra como lista la columna nombre
# Out:
# ['Ana', 'Luis', 'Carlos', 'María']

# %%
data['Nombre'] #solo llama a la columna
# Out:
# 0       Ana
# 1      Luis
# 2    Carlos
# 3     María
# Name: Nombre, dtype: object

# %%
data[['Nombre','Edad']].head() #para sacar por mas headings
# Out:
#    Nombre  Edad
# 0     Ana    23
# 1    Luis    45
# 2  Carlos    34
# 3   María    29

# %%
# Acceder a una columna
edades = data['Edad']
print("Edades:")
print(edades) #de por si ya comprende que solo quieres la data
# Out:
# Edades:
# 0    23
# 1    45
# 2    34
# 3    29
# Name: Edad, dtype: int64

# %%
# Acceder a múltiples columnas
nombre_ciudad = data[['Nombre', 'Ciudad']]
print("\nNombre y Ciudad:")
print(nombre_ciudad) #en caso sea dos columnas ya te lo da seteado
# Out:
# Nombre y Ciudad:
#    Nombre     Ciudad
# 0     Ana     Madrid
# 1    Luis  Barcelona
# 2  Carlos   Valencia
# 3   María    Sevilla

# %%
# Acceder a una fila por etiqueta #Tanto LOC como ILOC es como un lookup para filas
fila_ana = data.loc[0]
print("\nFila de Ana:")
print(fila_ana)
# Out:
# Fila de Ana:
# Nombre       Ana
# Edad          23
# Ciudad    Madrid
# Name: 0, dtype: object

# %%
# Acceder a una fila por posición
fila_primera = data.iloc[0]
print("\nPrimera fila:")
print(fila_primera)
# Out:
# Primera fila:
# Nombre       Ana
# Edad          23
# Ciudad    Madrid
# Name: 0, dtype: object

# %% [markdown]
# ### 2.2. Selección y filtrado
#
# Conceptos clave:
#
# - Filtrado condicional.
# - Uso de operadores lógicos (&, |, ~).
#
# **Ejemplo:**

# %%
df = pd.read_csv('/content/titanic.csv') #llamamos a que python lea el archivo

# %%
#Location

df.loc[df.Age <30].head() #se pueden poner filtros internos por locacion o lo que necesitemos, recordar head llama a los 5 primeras filas
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
#index location

df.iloc[[1,2,3,4,5]] #se quedan con las filas que se me antoje, esto es lista, se aplica una lista

df.iloc[100:120] #por ejemplo tambien llamar como slicing, esto es slicing

df.iloc [100] #llama a solo un usuario, esto es solo 1
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
df.head() #los 5 primero
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df.Embarked.isin(['C'])] #isin(listado) #pero hay varias maneras de llamar a una columna
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch         Ticket     Fare Cabin Embarked
# 1        0       PC 17599  71.2833   C85        C
# 9        0         237736  30.0708   NaN        C
# 19       0           2649   7.2250   NaN        C
# 26       0           2631   7.2250   NaN        C
# 30       0       PC 17601  27.7208   NaN        C
# ..     ...            ...      ...   ...      ...
# 866      0  SC/PARIS 2149  13.8583   NaN        C
# 874      0      P/PP 3381  24.0000   NaN        C
# 875      0           2667   7.2250   NaN        C
# 879      1          11767  83.1583   C50        C
# 889      0         111369  30.0000  C148        C
#
# [168 rows x 12 columns]

# %%
#filtremos el dataframe de titanic en mujeres de primera clase menores de 20 años
#Cuantos registros tienen el dataset?

condition1 = df['Sex'] == 'female' #Trabajaremos asi a apartir de ahora que es mas seguro xd
condition2 = df['Pclass'] == 1
condition3 = df['Age'] < 20 #todo lo que esta adentro del igual es la condicion

res = df[condition1 & condition2 & condition3] #se genera la nueva lista con las condiciones creadas
res
# Out:
#      PassengerId  Survived  Pclass  \
# 136          137         1       1
# 291          292         1       1
# 297          298         0       1
# 307          308         1       1
# 311          312         1       1
# 329          330         1       1
# 435          436         1       1
# 504          505         1       1
# 585          586         1       1
# 689          690         1       1
# 700          701         1       1
# 781          782         1       1
# 853          854         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 136                       Newsom, Miss. Helen Monypeny  female  19.0      0
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0      1
# 297                       Allison, Miss. Helen Loraine  female   2.0      1
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# 329                       Hippach, Miss. Jean Gertrude  female  16.0      0
# 435                          Carter, Miss. Lucile Polk  female  14.0      1
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 585                                Taussig, Miss. Ruth  female  18.0      0
# 689                  Madill, Miss. Georgette Alexandra  female  15.0      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare            Cabin Embarked
# 136      2     11752   26.2833              D47        S
# 291      0     11967   91.0792              B49        C
# 297      2    113781  151.5500          C22 C26        S
# 307      0  PC 17758  108.9000              C65        C
# 311      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 329      1    111361   57.9792              B18        C
# 435      2    113760  120.0000          B96 B98        S
# 504      0    110152   86.5000              B79        S
# 585      2    110413   79.6500              E68        S
# 689      1     24160  211.3375               B5        S
# 700      0  PC 17757  227.5250          C62 C64        C
# 781      0     17474   57.0000              B20        S
# 853      1  PC 17592   39.4000              D28        S
# 887      0    112053   30.0000              B42        S

# %%
res.Survived.mean() #saca la media de las condiciones ya filtradas, osea se trabaja como una nueva lista
# Out:
# 0.9285714285714286

# %%
res.shape #la forma de la matriz
# Out:
# (14, 12)

# %%
len(res) #cuantas filas hay, es decir personas
# Out:
# 14

# %%
res.info() #obtiene la informacion del nueva matriz o listado de columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 136 to 887
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  14 non-null     int64
#  1   Survived     14 non-null     int64
#  2   Pclass       14 non-null     int64
#  3   Name         14 non-null     object
#  4   Sex          14 non-null     object
#  5   Age          14 non-null     float64
#  6   SibSp        14 non-null     int64
#  7   Parch        14 non-null     int64
#  8   Ticket       14 non-null     object
#  9   Fare         14 non-null     float64
#  10  Cabin        14 non-null     object
#  11  Embarked     14 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.4+ KB

# %%
# Filtrar por condición
mayores_30 = df[df['Age'] > 30]
print("\nPersonas mayores de 30 años:")
mayores_30
# Out:
# Personas mayores de 30 años:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 4        0    373450   8.0500   NaN        S
# 6        0     17463  51.8625   E46        S
# 11       0    113783  26.5500  C103        S
# ..     ...       ...      ...   ...      ...
# 873      0    345765   9.0000   NaN        S
# 879      1     11767  83.1583   C50        C
# 881      0    349257   7.8958   NaN        S
# 885      5    382652  29.1250   NaN        Q
# 890      0    370376   7.7500   NaN        Q
#
# [305 rows x 12 columns]

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María'],
    'Edad': [23, 45, 34, 29],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla']
}

data = pd.DataFrame(data)
data.to_csv('/content/data', index=False)

# %%
# Filtrar por múltiples condiciones
madrid_menor_25 = data[(data['Ciudad'] == 'Madrid') & (data['Edad'] < 25)]
print("\nPersonas de Madrid mayores de 25 años:")
madrid_menor_25
# Out:
# Personas de Madrid mayores de 25 años:
#   Nombre  Edad  Ciudad
# 0    Ana    23  Madrid

# %%
# Uso de isin para múltiples valores
ciudades = data[data['Ciudad'].isin(['Madrid', 'Valencia'])]
print("\nPersonas de Madrid o Valencia:")
print(ciudades)
# Out:
# Personas de Madrid o Valencia:
#    Nombre  Edad    Ciudad
# 0     Ana    23    Madrid
# 2  Carlos    34  Valencia

# %% [markdown]
# ### 2.3. Ordenamiento de datos
#
# **Conceptos clave:**
#
# - Ordenar por una o varias columnas.
# - Orden ascendente (ascending=True) y descendente (ascending=False).
#
# **Ejemplo:**

# %%
df.sort_values(by = 'Age', ascending = False).head() #True es ascendente, y Falses es descente, sin embargo el indice no se modifica
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
df.sort_values(by = 'Age', ascending = False).reset_index() #para resetear los indices de nuevo, muy util
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0      630          631         1       1
# 1      851          852         0       3
# 2      493          494         0       1
# 3       96           97         0       1
# 4      116          117         0       3
# ..     ...          ...       ...     ...
# 886    859          860         0       3
# 887    863          864         0       3
# 888    868          869         0       3
# 889    878          879         0       3
# 890    888          889         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 0        Barkworth, Mr. Algernon Henry Wilson    male  80.0      0      0
# 1                         Svensson, Mr. Johan    male  74.0      0      0
# 2                     Artagaveytia, Mr. Ramon    male  71.0      0      0
# 3                   Goldschmidt, Mr. George B    male  71.0      0      0
# 4                        Connors, Mr. Patrick    male  70.5      0      0
# ..                                        ...     ...   ...    ...    ...
# 886                          Razi, Mr. Raihed    male   NaN      0      0
# 887         Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8      2
# 888               van Melkebeke, Mr. Philemon    male   NaN      0      0
# 889                        Laleff, Mr. Kristo    male   NaN      0      0
# 890  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 0         27042  30.0000   A23        S
# 1        347060   7.7750   NaN        S
# 2      PC 17609  49.5042   NaN        C
# 3      PC 17754  34.6542    A5        C
# 4        370369   7.7500   NaN        Q
# ..          ...      ...   ...      ...
# 886        2629   7.2292   NaN        C
# 887    CA. 2343  69.5500   NaN        S
# 888      345777   9.5000   NaN        S
# 889      349217   7.8958   NaN        S
# 890  W./C. 6607  23.4500   NaN        S
#
# [891 rows x 13 columns]

# %%
# Ordenar por edad ascendente
df_ordenado_edad = df.sort_values(by='Edad')
print("\nDataFrame ordenado por edad (ascendente):")
print(df_ordenado_edad)

# %%
# Ordenar por edad descendente
df_ordenado_edad_desc = df.sort_values(by='Edad', ascending=False)
print("\nDataFrame ordenado por edad (descendente):")
print(df_ordenado_edad_desc)

# %%
# Ordenar por ciudad y luego por edad
df_ordenado_ciudad_edad = df.sort_values(by=['Ciudad', 'Edad']) #primero ordena por ciudad y luego por edad
print("\nDataFrame ordenado por ciudad y edad:")
print(df_ordenado_ciudad_edad)

# %% [markdown]
# ### 2.4. Modificación y eliminación de datos
#
# **Conceptos clave:**
#
# - Añadir y modificar columnas.
# - Eliminar filas y columnas.
#
# **Ejemplo:**

# %%
df = pd.read_csv('/content/titanic.csv') #llamamos a que python lea el archivo

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['num_familiar'] = df['SibSp'] + df['Parch'] #df ['creame esta columna'] = df['Serie 1'] + num['Serie 2] otroa lista todo se puede, solo te
#pide que tiene que ser del mismo tamano

# %%
df['Constant'] = 1 #agrega numeros constantes

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  num_familiar  Constant
# 0      0         A/5 21171   7.2500   NaN        S             1         1
# 1      0          PC 17599  71.2833   C85        C             1         1
# 2      0  STON/O2. 3101282   7.9250   NaN        S             0         1
# 3      0            113803  53.1000  C123        S             1         1
# 4      0            373450   8.0500   NaN        S             0         1

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María'],
    'Edad': [23, 45, 34, 29],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla']
}

data = pd.DataFrame(data)
data.to_csv('/content/data', index=False)

# %%
# Añadir una nueva columna
data['Puntaje'] = [88, 92, 79, 85] #nueva columna se crea
print("\nDataFrame con nueva columna 'Puntaje':")
print(data)
# Out:
# DataFrame con nueva columna 'Puntaje':
#    Nombre  Edad     Ciudad  Puntaje
# 0     Ana    24     Madrid       88
# 1    Luis    45  Barcelona       92
# 2  Carlos    34   Valencia       79
# 3   María    29    Sevilla       85

# %%
# Modificar valores
data.loc[data['Nombre'] == 'Ana', 'Edad'] = 24 #modifica un valor especifico, al igual que Datos.loc[Datos[nombre de columna] == 'condicion'] para especificar que cambiar
print("\nDataFrame después de modificar la edad de Ana:")
print(data)
# Out:
# DataFrame después de modificar la edad de Ana:
#    Nombre  Edad     Ciudad  Puntaje
# 0     Ana    24     Madrid       88
# 1    Luis    45  Barcelona       92
# 2  Carlos    34   Valencia       79
# 3   María    29    Sevilla       85

# %%
# Eliminar una columna
df_sin_puntaje = data.drop('Puntaje', axis=1) #selecciona la columna
print("\nDataFrame sin la columna 'Puntaje':")
print(df_sin_puntaje) #siempre usar print
# Out:
# DataFrame sin la columna 'Puntaje':
#    Nombre  Edad     Ciudad
# 0     Ana    24     Madrid
# 1    Luis    45  Barcelona
# 2  Carlos    34   Valencia
# 3   María    29    Sevilla

# %%
# Eliminar una fila
data_sin_fila = data.drop(2)  # Eliminar la fila con índice 2
print("\nDataFrame sin la fila de Carlos:")
print(data_sin_fila)
# Out:
# DataFrame sin la fila de Carlos:
#   Nombre  Edad     Ciudad
# 0    Ana    23     Madrid
# 1   Luis    45  Barcelona
# 3  María    29    Sevilla

# %% [markdown]
# ### 2.5. Manejo de datos faltantes
#
# **Conceptos clave:**
#
# - Identificar y tratar valores nulos (NaN).
# - Métodos para eliminar o imputar datos faltantes.
#
# **Ejemplo:**

# %%
# Introducir valores faltantes
df_con_nan = data.copy()
df_con_nan.loc[1, 'Edad'] = None  # Introduce un valor faltante en la fila 1, columna 'Edad', se puede concatenar [pos_fila, 'Indicar columna']
print("\nDataFrame con valor faltante:")
print(df_con_nan)
# Out:
# DataFrame con valor faltante:
#    Nombre  Edad     Ciudad
# 0     Ana  23.0     Madrid
# 1    Luis   NaN  Barcelona
# 2  Carlos  34.0   Valencia
# 3   María  29.0    Sevilla

# %%
# Identificar valores faltantes
print("\nValores faltantes en 'Edad':")
print(df_con_nan['Edad'].isnull()) #isnull() identifica todos los valores que son Nune o null, siempre especificando la columna
# Out:
# Valores faltantes en 'Edad':
# 0    False
# 1     True
# 2    False
# 3    False
# Name: Edad, dtype: bool

# %%
# Eliminar filas con valores faltantes
df_sin_nan = df_con_nan.dropna() #elimina la fila que contenga nulls
print("\nDataFrame sin filas con valores faltantes:")
print(df_sin_nan)
# Out:
# DataFrame sin filas con valores faltantes:
#    Nombre  Edad    Ciudad
# 0     Ana  23.0    Madrid
# 2  Carlos  34.0  Valencia
# 3   María  29.0   Sevilla

# %%
# Imputar valores faltantes
df_imputado = df_con_nan.fillna({'Edad': df_con_nan['Edad'].mean()}) #el fillna funciona con ({nom_coll: llamado de la columna[].mean()}) en caso se quiera la media
print("\nDataFrame con valores faltantes imputados:")
print(df_imputado)
# Out:
# DataFrame con valores faltantes imputados:
#    Nombre       Edad     Ciudad
# 0     Ana  23.000000     Madrid
# 1    Luis  28.666667  Barcelona
# 2  Carlos  34.000000   Valencia
# 3   María  29.000000    Sevilla

# %% [markdown]
# ###2.6. Tamaño y resumen de datos
#
# **Conceptos clave:**
#
# - Obtener el número de filas y columnas.
# - Resumen estadístico de los datos.
#
# **Ejemplo:**

# %%
# Obtener el número de filas y columnas
filas, columnas = df.shape
print(f"\nEl DataFrame tiene {filas} filas y {columnas} columnas.")
# Out:
# El DataFrame tiene 891 filas y 14 columnas.

# %%
# Listar las columnas
print("\nColumnas del DataFrame:")
print(df.columns) #basicamente muestra el titulo de cada columna
# Out:
# Columnas del DataFrame:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'num_familiar',
#        'Constant'],
#       dtype='object')

# %%
# Resumen estadístico
print("\nResumen estadístico:")
print(df.describe())
# Out:
# Resumen estadístico:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  num_familiar  Constant
# count  891.000000  891.000000    891.000000     891.0
# mean     0.381594   32.204208      0.904602       1.0
# std      0.806057   49.693429      1.613459       0.0
# min      0.000000    0.000000      0.000000       1.0
# 25%      0.000000    7.910400      0.000000       1.0
# 50%      0.000000   14.454200      0.000000       1.0
# 75%      0.000000   31.000000      1.000000       1.0
# max      6.000000  512.329200     10.000000       1.0

# %% [markdown]
# ### 2.7. Ejercicios

# %% [markdown]
# **Ejercicio 1**
#
# Crea un DataFrame con la siguiente información:
#
# - Nombre: 'Juan', 'Laura', 'Pedro', 'Carmen', 'Luis'
# - Departamento: 'Ventas', 'Marketing', 'Ventas', 'Finanzas', 'Marketing'
# - Salario: 50000, 60000, 55000, 65000, 62000
#
# Tareas:
#
# - Accede a la columna de salarios.
# - Filtra los empleados del departamento de 'Marketing'.
# - Ordena el DataFrame por salario de manera descendente.
# - Añade una nueva columna 'Bono' que sea el 10% del salario.
# - Calcula el salario total (salario + bono) y añade una columna 'SalarioTotal'.

# %%
info = {
    'Nombre': ['Juan', 'Laura', 'Pedro', 'Carmen','Luis'],
    'Departamento': ['Ventas', 'Marketing', 'Ventas', 'Finanzas', 'Marketing'],
    'Salario': [50000, 60000, 55000, 65000, 62000]
}

data1 = pd.DataFrame(info)
data1.to_csv('/content/Data1', index=False)

salarios = data1['Salario']
print("Salarios:")
print(salarios)

marketing = data1[data1.Departamento == 'Marketing']
print("\nEmpleados del departamento de Marketing:")
print(marketing)

ordenado = data1.sort_values(by='Salario', ascending=False) #recordar que no cambia los id de las filas
print("\nDataFrame ordenado por salario (descendente):")
print(ordenado)

data1['Bono'] = data1['Salario'] * 0.1
print("\nDataFrame con columna 'Bono':")
print(data1)

data1['SalarioTotal'] = data1['Salario'] + data1['Bono']
print("\nDataFrame con columna 'SalarioTotal':")
print(data1)
# Out:
# Salarios:
# 0    50000
# 1    60000
# 2    55000
# 3    65000
# 4    62000
# Name: Salario, dtype: int64
#
# Empleados del departamento de Marketing:
#   Nombre Departamento  Salario
# 1  Laura    Marketing    60000
# 4   Luis    Marketing    62000
#
# DataFrame ordenado por salario (descendente):
#    Nombre Departamento  Salario
# 3  Carmen     Finanzas    65000
# 4    Luis    Marketing    62000
# 1   Laura    Marketing    60000
# 2   Pedro       Ventas    55000
# 0    Juan       Ventas    50000
#
# DataFrame con columna 'Bono':
#    Nombre Departamento  Salario    Bono
# 0    Juan       Ventas    50000  5000.0
# 1   Laura    Marketing    60000  6000.0
# 2   Pedro       Ventas    55000  5500.0
# 3  Carmen     Finanzas    65000  6500.0
# 4    Luis    Marketing    62000  6200.0
#
# DataFrame con columna 'SalarioTotal':
#    Nombre Departamento  Salario    Bono  SalarioTotal
# 0    Juan       Ventas    50000  5000.0       55000.0
# 1   Laura    Marketing    60000  6000.0       66000.0
# 2   Pedro       Ventas    55000  5500.0       60500.0
# 3  Carmen     Finanzas    65000  6500.0       71500.0
# 4    Luis    Marketing    62000  6200.0       68200.0

# %% [markdown]
# **Ejercicio 2**
#
# Utilizando el DataFrame del ejercicio anterior:
#
# - Modifica el salario de 'Juan' a 52000.
# - Elimina el empleado 'Pedro' del DataFrame.
# - Identifica si hay datos faltantes en el DataFrame.
# - Si hay datos faltantes, imputa con el valor promedio de la columna correspondiente.

# %%
data1.loc[data1.Nombre == 'Juan', 'Salario'] = 52000
print("\nDataFrame con salario de Juan modificado:")
print(data1)

sin_pedro = data1[data1.Nombre != 'Pedro'] #se puede aplicar un filtrado
print("\nDataFrame sin Pedro:")
print(sin_pedro)

print("\nDatos faltantes en el DataFrame:")
print(data1.isnull())

data1_imputado = data1.fillna({'Salario': data1['Salario'].mean()})
print("\nDataFrame con valores faltantes imputados:")
print(data1_imputado)
# Out:
# DataFrame con salario de Juan modificado:
#    Nombre Departamento  Salario    Bono  SalarioTotal
# 0    Juan       Ventas    52000  5000.0       55000.0
# 1   Laura    Marketing    60000  6000.0       66000.0
# 3  Carmen     Finanzas    65000  6500.0       71500.0
# 4    Luis    Marketing    62000  6200.0       68200.0
#
# DataFrame sin Pedro:
#    Nombre Departamento  Salario    Bono  SalarioTotal
# 0    Juan       Ventas    52000  5000.0       55000.0
# 1   Laura    Marketing    60000  6000.0       66000.0
# 3  Carmen     Finanzas    65000  6500.0       71500.0
# 4    Luis    Marketing    62000  6200.0       68200.0
#
# Datos faltantes en el DataFrame:
#    Nombre  Departamento  Salario   Bono  SalarioTotal
# 0   False         False    False  False         False
# 1   False         False    False  False         False
# 3   False         False    False  False         False
# 4   False         False    False  False         False
#
# DataFrame con valores faltantes imputados:
#    Nombre Departamento  Salario    Bono  SalarioTotal
# 0    Juan       Ventas    52000  5000.0       55000.0
# 1   Laura    Marketing    60000  6000.0       66000.0
# 3  Carmen     Finanzas    65000  6500.0       71500.0
# 4    Luis    Marketing    62000  6200.0       68200.0

# %% [markdown]
# **Ejercicio 3**
#
# Crea un DataFrame con datos de ventas:
#
# - Producto: 'Producto A', 'Producto B', 'Producto C', 'Producto D'
# - Ventas Enero: 150, 200, 140, 170
# - Ventas Febrero: 180, None, 160, 190
#
# Tareas:
#
# - Calcula el total de ventas por producto sumando 'Ventas Enero' y 'Ventas Febrero'.
# - Identifica los productos con datos faltantes en 'Ventas Febrero'.
# - Imputa los valores faltantes con el promedio de 'Ventas Febrero'.
# - Ordena el DataFrame por total de ventas de manera ascendente.

# %%
vivi = {
    'Producto': ['Producto A', 'Producto B', 'Producto C', 'Producto D'],
    'Ventas Enero': [150, 200, 140, 170],
    'Ventas Febrero': [180, None, 160, 190]
}

vivi = pd.DataFrame(vivi)
vivi.to_csv('/content/vivi', index=False)

vivi['Total de ventas'] = vivi['Ventas Enero'] + vivi['Ventas Febrero']
print("\nDataFrame con columna 'Total de ventas':")
print(vivi)

print("\nDatos faltantes en el DataFrame:")
print(vivi.isnull())

vivi_imputado = vivi.fillna({'Ventas Febrero': vivi['Ventas Febrero'].mean()})
vivi_imputado['Total de ventas'] = vivi_imputado['Ventas Enero'] + vivi_imputado['Ventas Febrero']
print("\nDataFrame con valores faltantes imputados:")
print(vivi_imputado)

ordenado = vivi_imputado.sort_values(by='Total de ventas', ascending = True)
print("\nDataFrame ordenado por total de ventas (ascendente):")
print(ordenado)
# Out:
# DataFrame con columna 'Total de ventas':
#      Producto  Ventas Enero  Ventas Febrero  Total de ventas
# 0  Producto A           150           180.0            330.0
# 1  Producto B           200             NaN              NaN
# 2  Producto C           140           160.0            300.0
# 3  Producto D           170           190.0            360.0
#
# Datos faltantes en el DataFrame:
#    Producto  Ventas Enero  Ventas Febrero  Total de ventas
# 0     False         False           False            False
# 1     False         False            True             True
# 2     False         False           False            False
# 3     False         False           False            False
#
# DataFrame con valores faltantes imputados:
#      Producto  Ventas Enero  Ventas Febrero  Total de ventas
# 0  Producto A           150      180.000000       330.000000
# 1  Producto B           200      176.666667       376.666667
# 2  Producto C           140      160.000000       300.000000
# 3  Producto D           170      190.000000       360.000000
#
# DataFrame ordenado por total de ventas (ascendente):
#      Producto  Ventas Enero  Ventas Febrero  Total de ventas
# 2  Producto C           140      160.000000       300.000000
# 0  Producto A           150      180.000000       330.000000
# 3  Producto D           170      190.000000       360.000000
# 1  Producto B           200      176.666667       376.666667

# %% [markdown]
# ## 3. Combinación de Datasets

# %% [markdown]
# ### 3.1. Métodos de combinación: merge, join, concat
#
# Pandas ofrece varias funciones para combinar y fusionar DataFrames:
#
# - **pd.merge:** Combina DataFrames basándose en una o más claves comunes; similar a las uniones (joins) de SQL.
# - **pd.DataFrame.join:** Combina DataFrames basándose en los índices.
# - **pd.concat:** Une DataFrames a lo largo de un eje (filas o columnas).

# %% [markdown]
# ### 3.2. Combinación uno a uno
#
# **Ejemplo:**

# %%
# DataFrame de empleados
df_empleados = pd.DataFrame({
    'EmpleadoID': [1, 2, 3],
    'Nombre': ['John', 'Anna', 'Peter'],
    'DepartamentoID': [101, 102, 103]
})

# DataFrame de departamentos
df_departamentos = pd.DataFrame({
    'DepartamentoID': [101, 102, 103],
    'Departamento': ['HR', 'IT', 'Marketing']
})

# Combinar los DataFrames
df_combined = pd.merge(df_empleados, df_departamentos, on='DepartamentoID') #debe tener un pivot en donde se entrelazen
print("\nDataFrame combinado (uno a uno):")
print(df_combined)
# Out:
# DataFrame combinado (uno a uno):
#    EmpleadoID Nombre  DepartamentoID Departamento
# 0           1   John             101           HR
# 1           2   Anna             102           IT
# 2           3  Peter             103    Marketing

# %% [markdown]
# ### 3.3. Combinación muchos a uno
#
# **Ejemplo:**

# %%
# DataFrame de pedidos
df_pedidos = pd.DataFrame({
    'PedidoID': [1001, 1002, 1003, 1004],
    'ClienteID': [1, 1, 2, 3],
    'Monto': [250, 150, 400, 130]
})

# DataFrame de clientes
df_clientes = pd.DataFrame({
    'ClienteID': [1, 2, 3],
    'Cliente': ['Alice', 'Bob', 'Charlie']
})

# Combinar los DataFrames
df_pedidos_clientes = pd.merge(df_pedidos, df_clientes, on='ClienteID') #si se repite a un uno
print("\nDataFrame combinado (muchos a uno):")
print(df_pedidos_clientes)
# Out:
# DataFrame combinado (muchos a uno):
#    PedidoID  ClienteID  Monto  Cliente
# 0      1001          1    250    Alice
# 1      1002          1    150    Alice
# 2      1003          2    400      Bob
# 3      1004          3    130  Charlie

# %% [markdown]
# ### 3.4. Combinación muchos a muchos
#
# **Ejemplo:**

# %%
# DataFrame de estudiantes
df_estudiantes = pd.DataFrame({
    'EstudianteID': [1, 2, 3],
    'Nombre': ['Laura', 'Kevin', 'Sophie']
})

# DataFrame de cursos
df_cursos = pd.DataFrame({
    'CursoID': [101, 102],
    'Curso': ['Matemáticas', 'Ciencias']
})

# DataFrame de inscripciones
df_inscripciones = pd.DataFrame({
    'EstudianteID': [1, 1, 2, 3, 3],
    'CursoID': [101, 102, 101, 101, 102]
})

# Combinar los DataFrames
df_full = pd.merge(pd.merge(df_inscripciones, df_estudiantes, on='EstudianteID'),
                   df_cursos, on='CursoID') #hace primero el pivote de inscripciones con estudiantes y luego por afuera hace con cursos de la nueva tabla
print("\nDataFrame combinado (muchos a muchos):")
print(df_full)
# Out:
# DataFrame combinado (muchos a muchos):
#    EstudianteID  CursoID  Nombre        Curso
# 0             1      101   Laura  Matemáticas
# 1             1      102   Laura     Ciencias
# 2             2      101   Kevin  Matemáticas
# 3             3      101  Sophie  Matemáticas
# 4             3      102  Sophie     Ciencias

# %% [markdown]
# ### 3.5. Concatenación de datasets
#
# **Concatenación vertical (añadir filas):**

# %%
# DataFrames de ventas de dos meses
df_enero = pd.DataFrame({
    'Producto': ['A', 'B'],
    'Ventas': [100, 150]
})

df_febrero = pd.DataFrame({
    'Producto': ['A', 'B'],
    'Ventas': [200, 250]
})

# Concatenar los DataFrames
df_ventas = pd.concat([df_enero, df_febrero], keys=['Enero', 'Febrero']) #en este caso los keys se vuelven los datos o filas verticales
print("\nDataFrame concatenado (vertical):")
print(df_ventas)
# Out:
# DataFrame concatenado (vertical):
#           Producto  Ventas
# Enero   0        A     100
#         1        B     150
# Febrero 0        A     200
#         1        B     250

# %% [markdown]
# **Concatenación horizontal (añadir columnas):**

# %%
# DataFrames de características
df_caracteristicas1 = pd.DataFrame({
    'ID': [1, 2],
    'Caracteristica1': ['X', 'Y']
})

df_caracteristicas2 = pd.DataFrame({
    'ID': [1, 2],
    'Caracteristica2': ['Z', 'W']
})

# Establecer 'ID' como índice
df_caracteristicas1.set_index('ID', inplace=True) #el ID de los dataframes se vuelve la data
df_caracteristicas2.set_index('ID', inplace=True)

# Concatenar los DataFrames
df_caracteristicas = pd.concat([df_caracteristicas1, df_caracteristicas2], axis=1) # se concatena en columnas con el axis = 1
print("\nDataFrame concatenado (horizontal):")
print(df_caracteristicas)
# Out:
# DataFrame concatenado (horizontal):
#    Caracteristica1 Caracteristica2
# ID
# 1                X               Z
# 2                Y               W

# %% [markdown]
# ### 3.6. Ejercicios
#
# **Ejercicio 1**
#
# Tienes dos DataFrames:
#
# - df_productos con columnas ProductoID, Producto, Categoría.
# - df_precios con columnas ProductoID, Precio.
#
# Tareas:
# - Realiza un merge para obtener un DataFrame que contenga toda la información de productos y sus precios.
# - Experimenta con los diferentes tipos de combinación: inner, outer, left, right.
# - Analiza cómo cambia el resultado con cada tipo de combinación.

# %%
df_productos = pd.DataFrame({
    'ProductoID': [1, 2, 3],
    'Producto': ['A', 'B', 'C'],
    'Categoría': ['X', 'Y', 'Z']
})

df_precios = pd.DataFrame({
    'ProductoID': [2, 3, 4],
    'Precio': [10, 15, 20]
})

df_merge = pd.merge(df_productos, df_precios, on='ProductoID')
print("\nDataFrame combinado")
print(df_merge)

df_inner = pd.merge(df_productos, df_precios, on='ProductoID', how = 'inner')
print("\nDataFrame combinado (inner):")
print(df_inner)

df_outer = pd.merge(df_productos, df_precios, on='ProductoID', how = 'outer')
print("\nDataFrame combinado (inner):")
print(df_outer)

df_right = pd.merge(df_productos, df_precios, on='ProductoID', how = 'right')
print("\nDataFrame combinado (inner):")
print(df_right)

df_left = pd.merge(df_productos, df_precios, on='ProductoID', how = 'right')
print("\nDataFrame combinado (inner):")
print(df_right)
# Out:
# DataFrame combinado
#    ProductoID Producto Categoría  Precio
# 0           2        B         Y      10
# 1           3        C         Z      15
#
# DataFrame combinado (inner):
#    ProductoID Producto Categoría  Precio
# 0           2        B         Y      10
# 1           3        C         Z      15
#
# DataFrame combinado (inner):
#    ProductoID Producto Categoría  Precio
# 0           1        A         X     NaN
# 1           2        B         Y    10.0
# 2           3        C         Z    15.0
# 3           4      NaN       NaN    20.0
#
# DataFrame combinado (inner):
#    ProductoID Producto Categoría  Precio
# 0           2        B         Y      10
# 1           3        C         Z      15
# 2           4      NaN       NaN      20

# %% [markdown]
# **Ejercicio 2**
#
# Tienes los siguientes DataFrames:
#
# - df_ventas_Q1 con ventas del primer trimestre.
# - df_ventas_Q2 con ventas del segundo trimestre.
#
# Ambos tienen las mismas columnas: Producto, Ventas.
#
# Tareas:
#
# - Concatenar los DataFrames para tener las ventas del semestre.
# - Añade una clave para identificar el trimestre al que pertenece cada fila.
# - Calcula las ventas totales por producto en el semestre.

# %%
import pandas as pd

df_ventas_Q1 = pd.DataFrame({
    'Producto': ['A', 'B', 'C'],
    'Ventas': [100, 150, 200]
})

df_ventas_Q2 = pd.DataFrame({
    'Producto': ['A', 'B', 'D'],
    'Ventas': [120, 180, 250]
})

df_ventas_semestre = pd.concat([df_ventas_Q1, df_ventas_Q2], keys=['Q1', 'Q2']) #les da el key al que estan unidos y crea una nueva variable

df_ventas_semestre = df_ventas_semestre.reset_index(level=0) #reseteamos el index
df_ventas_semestre = df_ventas_semestre.rename(columns={'level_0': 'Trimestre'}) #cambiamos de nombre

ventas_totales = df_ventas_semestre.groupby('Producto')['Ventas'].sum()


print("Ventas del semestre:")
print(df_ventas_semestre)

print("\nVentas totales por producto:")
ventas_totales
# Out:
# Ventas del semestre:
#   Trimestre Producto  Ventas
# 0        Q1        A     100
# 1        Q1        B     150
# 2        Q1        C     200
# 0        Q2        A     120
# 1        Q2        B     180
# 2        Q2        D     250
#
# Ventas totales por producto:
# Producto
# A    220
# B    330
# C    200
# D    250
# Name: Ventas, dtype: int64

# %% [markdown]
# **Ejercicio 3**
#
# Supongamos que tienes dos DataFrames con índices diferentes:
#
# - df_empleados indexado por EmpleadoID y columnas Nombre, Departamento.
# - df_salarios indexado por Nombre y columna Salario.
#
# Tareas:
#
# - Combina estos DataFrames utilizando join para obtener un DataFrame que contenga EmpleadoID, Nombre, Departamento y Salario.
# - Asegúrate de manejar correctamente los índices para que la combinación sea exitosa.
# - Identifica y maneja cualquier inconsistencia en los datos (por ejemplo, nombres que no coinciden).

# %%
import pandas as pd

df_empleados = pd.DataFrame({
    'EmpleadoID': [1, 2, 3, 4],
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María'],
    'Departamento': ['Ventas', 'Marketing', 'Ventas', 'Finanzas']
})
df_empleados = df_empleados.set_index('EmpleadoID')

df_salarios = pd.DataFrame({
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María'],
    'Salario': [50000, 60000, 55000, 65000]
})
df_salarios = df_salarios.set_index('Nombre')


df_combinado = df_empleados.join(df_salarios, on='Nombre', how='left')

df_combinado
# Out:
#             Nombre Departamento  Salario
# EmpleadoID
# 1              Ana       Ventas    50000
# 2             Luis    Marketing    60000
# 3           Carlos       Ventas    55000
# 4            María     Finanzas    65000

# %% [markdown]
# ## 4. Agregación y Agrupamiento

# %% [markdown]
# ### 4.1. El proceso groupby
#
# El método groupby permite:
#
# - Dividir: Separar el DataFrame en grupos basados en una o más claves.
# - Aplicar: Calcular una función específica en cada grupo.
# - Combinar: Unir los resultados en una estructura de datos.

# %% [markdown]
# ### 4.2. Funciones de agregación
#
# - Sumatorias: sum()
# - Promedios: mean()
# - Conteos: count()
# - Valores extremos: min(), max()
# - Medidas de dispersión: std(), var()

# %% [markdown]
# **Ejemplo:**

# %%
# DataFrame de ventas
df_ventas = pd.DataFrame({
    'Región': ['Norte', 'Sur', 'Este', 'Oeste', 'Norte', 'Sur'],
    'Ventas': [100, 150, 200, 130, 120, 170],
    'Ganancia': [20, 30, 50, 25, 22, 35]
})

# Agrupar por 'Región' y calcular la suma de 'Ventas' y 'Ganancia'
agrupado = df_ventas.groupby('Región').agg({'Ventas': 'sum', 'Ganancia': 'sum'}) #el agg es para agrupar, y se determina que se realiza en las siguientes columnas, suma etc
print("\nAgregación por región:")
print(agrupado)
# Out:
# Agregación por región:
#         Ventas  Ganancia
# Región
# Este       200        50
# Norte      220        42
# Oeste      130        25
# Sur        320        65

# %% [markdown]
# ### 4.3. Agrupamiento por múltiples claves
#
# **Ejemplo:**

# %%
# Agregar una columna 'Tipo' para demostrar agrupamiento múltiple
df_ventas['Tipo'] = ['Minorista', 'Mayorista', 'Minorista', 'Minorista', 'Mayorista', 'Minorista'] #agregamos esta columna a la tabla

# Agrupar por 'Región' y 'Tipo' y calcular el promedio de 'Ventas'
agrupado_multiple = df_ventas.groupby(['Región', 'Tipo']).mean() #agrupado por y que sea las ventas y ganancias como promedio
print("\nAgrupación por región y tipo:")
print(agrupado_multiple)
# Out:
# Agrupación por región y tipo:
#                   Ventas  Ganancia
# Región Tipo
# Este   Minorista   200.0      50.0
# Norte  Mayorista   120.0      22.0
#        Minorista   100.0      20.0
# Oeste  Minorista   130.0      25.0
# Sur    Mayorista   150.0      30.0
#        Minorista   170.0      35.0

# %% [markdown]
# ### 4.4. Operaciones de transformación
#
# Las transformaciones aplican una función a cada grupo y devuelven un objeto del mismo tamaño que el grupo original.
#
# **Ejemplo:**

# %%
# Calcular la diferencia de cada venta respecto al promedio de su región
df_ventas['PromedioVentasRegión'] = df_ventas.groupby('Región')['Ventas'].transform('mean')
df_ventas['DiferenciaVentas'] = df_ventas['Ventas'] - df_ventas['PromedioVentasRegión']
print("\nDataFrame con transformaciones:")
print(df_ventas)
# Out:
# DataFrame con transformaciones:
#   Región  Ventas  Ganancia       Tipo  PromedioVentasRegión  DiferenciaVentas
# 0  Norte     100        20  Minorista                 110.0             -10.0
# 1    Sur     150        30  Mayorista                 160.0             -10.0
# 2   Este     200        50  Minorista                 200.0               0.0
# 3  Oeste     130        25  Minorista                 130.0               0.0
# 4  Norte     120        22  Mayorista                 110.0              10.0
# 5    Sur     170        35  Minorista                 160.0              10.0

# %% [markdown]
# ### 4.5. Ejercicios
#
# **Ejercicio 1**
#
# Usando el DataFrame df_ventas:
#
# - Agrupa los datos por Región y calcula la media y suma de Ventas y Ganancia.
# - Ordena los resultados de mayor a menor en función de la suma de Ventas.
# - Visualiza los resultados utilizando un gráfico de barras.

# %%
# prompt: Usando el DataFrame df_ventas:
# Agrupa los datos por Región y calcula la media y suma de Ventas y Ganancia.
# Ordena los resultados de mayor a menor en función de la suma de Ventas.
# Visualiza los resultados utilizando un gráfico de barras.

import pandas as pd
import matplotlib.pyplot as plt

# DataFrame de ventas (reemplaza con tu DataFrame real)
df_ventas = pd.DataFrame({
    'Región': ['Norte', 'Sur', 'Este', 'Oeste', 'Norte', 'Sur', 'Este', 'Oeste', 'Norte', 'Sur'],
    'Ventas': [100, 150, 200, 130, 120, 170, 210, 140, 110, 160],
    'Ganancia': [20, 30, 50, 25, 22, 35, 45, 30, 20, 32]
})

# Agrupar por Región y calcular la media y suma de Ventas y Ganancia
agrupado = df_ventas.groupby('Región').agg({'Ventas': ['mean', 'sum'], 'Ganancia': ['mean', 'sum']})

# Aplanar los nombres de las columnas para facilitar el acceso
agrupado.columns = ['_'.join(col).strip() for col in agrupado.columns.values]

# Ordenar por la suma de ventas
agrupado_ordenado = agrupado.sort_values(by='Ventas_sum', ascending=False)

# Visualizar los resultados con un gráfico de barras
agrupado_ordenado['Ventas_sum'].plot(kind='bar')
plt.title('Suma de Ventas por Región')
plt.xlabel('Región')
plt.ylabel('Suma de Ventas')
plt.show()

# %% [markdown]
# **Ejercicio 2**
#
# Tienes un DataFrame df_estudiantes con las columnas Clase, Género, Puntuación.
#
# - Calcula la puntuación media por clase y género.
# - Encuentra la puntuación máxima y mínima por clase.
# - Normaliza las puntuaciones de cada estudiante restando la media de su clase.

# %%
import pandas as pd

data = {'Clase': ['A', 'A', 'B', 'B', 'A', 'B'],
        'Género': ['M', 'F', 'M', 'F', 'M', 'F'],
        'Puntuación': [85, 90, 78, 88, 92, 82]}
df_estudiantes = pd.DataFrame(data)

# Calcular la puntuación media por clase y género
puntuacion_media = df_estudiantes.groupby(['Clase', 'Género'])['Puntuación'].mean()
print("Puntuación media por clase y género:\n", puntuacion_media)

# Encontrar la puntuación máxima y mínima por clase
puntuacion_extremos = df_estudiantes.groupby('Clase')['Puntuación'].agg(['min', 'max'])
print("\nPuntuación máxima y mínima por clase:\n", puntuacion_extremos)

# Normalizar las puntuaciones de cada estudiante restando la media de su clase
def normalize_score(x):
  return x - x.mean()

df_estudiantes['Puntuación_normalizada'] = df_estudiantes.groupby('Clase')['Puntuación'].transform(normalize_score)
print("\nDataFrame con puntuaciones normalizadas:\n", df_estudiantes)
# Out:
# Puntuación media por clase y género:
#  Clase  Género
# A      F         90.0
#        M         88.5
# B      F         85.0
#        M         78.0
# Name: Puntuación, dtype: float64
#
# Puntuación máxima y mínima por clase:
#         min  max
# Clase
# A       85   92
# B       78   88
#
# DataFrame con puntuaciones normalizadas:
#    Clase Género  Puntuación  Puntuación_normalizada
# 0     A      M          85               -4.000000
# 1     A      F          90                1.000000
# 2     B      M          78               -4.666667
# 3     B      F          88                5.333333
# 4     A      M          92                3.000000
# 5     B      F          82               -0.666667

# %% [markdown]
# **Ejercicio 3**
#
# Con el DataFrame de ventas df_ventas, crea una función personalizada que calcule el rango intercuartílico (IQR) de las ventas por región.
#
# - Define una función que calcule el IQR.
# - Utiliza groupby() y agg() para aplicar esta función.
# - Interpreta los resultados.

# %%
def calcular_iqr(x):
  return x.quantile(0.75) - x.quantile(0.25)

# Aplicar la función al DataFrame de ventas
iqr_por_region = df_ventas.groupby('Región')['Ventas'].agg(calcular_iqr)

print("\nRango Intercuartílico (IQR) de ventas por región:")
iqr_por_region
# Out:
# Rango Intercuartílico (IQR) de ventas por región:
# Región
# Este      5.0
# Norte    10.0
# Oeste     5.0
# Sur      10.0
# Name: Ventas, dtype: float64

# %% [markdown]
# ---
#
# # Gracias por completar este laboratorio!
#
# ---
